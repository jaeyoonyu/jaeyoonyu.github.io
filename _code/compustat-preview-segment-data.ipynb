# %% [markdown]
# ## Compustat - Segment data
# - seg_ann
# - seg_annfund
# - seg_customer
# - seg_geo
# - seg_naics
# - seg_product
# - seg_type

# %% [markdown]
# -------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import wrds
pd.options.display.max_columns=200

# %% [markdown]
# ### Connect WRDS

# %%
conn=wrds.Connection()
# Out:
# Enter your WRDS username [yjaey]: yjaeyoon
# Enter your password: ···············
# WRDS recommends setting up a .pgpass file.
# Create .pgpass file now [y/n]?:  y
# Created .pgpass file successfully.
# Loading library list...
# Done

# %% [markdown]
# ----------------

# %%
uber_gvkey= '035077'

# %% [markdown]
# ### Define a function to get segment data for one company

# %%
def get_seg_data(seg_file , gvkey ):

    seg_df= conn.raw_sql(f"""select *
                        from comp.{file_name} a
                        where a.gvkey = '{uber_gvkey}' and a.datadate= '2019-12-31'
                        """)
    return seg_df

# %% [markdown]
# ---------------

# %% [markdown]
# ### seg_ann

# %%
file_name= 'seg_ann'
df= get_seg_data(file_name, uber_gvkey)
print(df.shape)
df.head()
# Out:
# (1, 7)
#     gvkey curcds isosrc  naicsh  srcs  upds    datadate
# 0  035077    USD   None  485310   5.0   3.0  2019-12-31

# %% [markdown]
# ---------------

# %% [markdown]
# ### seg_annfund

# %%
file_name= 'seg_annfund'
df= get_seg_data(file_name, uber_gvkey)
print(df.shape)
df.head()
# Out:
# (21, 79)
#     gvkey   stype  sid  atlls atlls_dc capxs capxs_dc capxs_fn caxts caxts_dc  \
# 0  035077  BUSSEG  3.0    NaN     None  None     None     None  None     None
# 1  035077  BUSSEG  4.0    NaN     None  None     None     None  None     None
# 2  035077  BUSSEG  5.0    NaN     None  None     None     None  None     None
# 3  035077  BUSSEG  6.0    NaN     None  None     None     None  None     None
# 4  035077  BUSSEG  7.0    NaN     None  None     None     None  None     None
#
#   cogss cogss_dc   dps dps_dc  emps emps_dc emps_fn esubs esubs_dc esubs_fn  \
# 0  None     None  None   None  None    None    None  None     None     None
# 1  None     None  None   None  None    None    None  None     None     None
# 2  None     None  None   None  None    None    None  None     None     None
# 3  None     None  None   None  None    None    None  None     None     None
# 4  None     None  None   None  None    None    None  None     None     None
#
# ...

# %% [markdown]
# ---------------

# %% [markdown]
# ### Customer

# %%
file_name= 'seg_customer'
df= get_seg_data(file_name, uber_gvkey)
print(df.shape)
df.head()
# Out:
# (4, 10)
#     gvkey  cid                            cnms   ctype  gareac gareat  salecs  \
# 0  035077  1.0        United States and Canada  GEOREG     USA    ISO  8805.0
# 1  035077  2.0                   Latin America  GEOREG  L_AMER    REG  1947.0
# 2  035077  3.0  Europe, Middle East and Africa  GEOREG  EUROPE    REG  2148.0
# 3  035077  4.0                    Asia Pacific  GEOREG    ASIA    REG  1247.0
#
#    sid stype    datadate
# 0  0.0  None  2019-12-31
# 1  0.0  None  2019-12-31
# 2  0.0  None  2019-12-31
# 3  0.0  None  2019-12-31

# %% [markdown]
# ---------------

# %% [markdown]
# ### Geographic

# %%
file_name= 'seg_geo'
df= get_seg_data(file_name, uber_gvkey)
print(df.shape)
df.head(20)
# Out:
# (3, 6)
#     gvkey   stype  sid gareag gareat    datadate
# 0  035077  GEOSEG  1.0    USA    ISO  2019-12-31
# 1  035077  GEOSEG  2.0    BRA    ISO  2019-12-31
# 2  035077  GEOSEG  3.0  OTHER    REG  2019-12-31

# %% [markdown]
# ---------------

# %% [markdown]
# ### naics (industry)

# %%
file_name= 'seg_naics'
df= get_seg_data(file_name, uber_gvkey)
print(df.shape)
df.head(20)
# Out:
# (9, 7)
#     gvkey   stype  sid  ranks  naicss  sics    datadate
# 0  035077  BUSSEG  2.0    1.0  541614  4731  2019-12-31
# 1  035077  BUSSEG  2.0    2.0     485  4100  2019-12-31
# 2  035077  BUSSEG  3.0    1.0  485310  4121  2019-12-31
# 3  035077  BUSSEG  3.0    2.0  519130  7375  2019-12-31
# 4  035077  BUSSEG  4.0    1.0  519130  7375  2019-12-31
# 5  035077  BUSSEG  4.0    2.0  485310  4121  2019-12-31
# 6  035077  BUSSEG  5.0    1.0  541614  4731  2019-12-31
# 7  035077  BUSSEG  5.0    2.0     485  4100  2019-12-31
# 8  035077  BUSSEG  6.0    1.0  519130  7375  2019-12-31

# %% [markdown]
# ---------------

# %% [markdown]
# ### product

# %%
file_name= 'seg_product'
df= get_seg_data(file_name, uber_gvkey)
print(df.shape)
df.head(20)
# Out:
# (3, 8)
#     gvkey  pdid  naicsp                       pnms   saleps  sid   stype  \
# 0  035077   5.0  485310              Rides revenue  10612.0  3.0  BUSSEG
# 1  035077   6.0  532111  Vehicle Solutions revenue     21.0  3.0  BUSSEG
# 2  035077   7.0  532111              Other revenue    112.0  3.0  BUSSEG
#
#      datadate
# 0  2019-12-31
# 1  2019-12-31
# 2  2019-12-31

# %% [markdown]
# ---------------

# %% [markdown]
# ### Type

# %%
file_name= 'seg_type'
df= get_seg_data(file_name, uber_gvkey)
print(df.shape)
df.head(20)
# Out:
# (8, 8)
#     gvkey   stype  sid geotp                               snms   soptp1  \
# 0  035077  BUSSEG  2.0  None                         Other Bets  PD_SRVC
# 1  035077  BUSSEG  3.0  None                              Rides  PD_SRVC
# 2  035077  BUSSEG  4.0  None                               Eats  PD_SRVC
# 3  035077  BUSSEG  5.0  None                            Freight  PD_SRVC
# 4  035077  BUSSEG  6.0  None  ATG and Other Technology Programs  PD_SRVC
# 5  035077  GEOSEG  1.0     2                      United States      GEO
# 6  035077  GEOSEG  2.0     3                             Brazil      GEO
# 7  035077  GEOSEG  3.0     3                All Other Countries      GEO
#
#   soptp2    datadate
# 0   None  2019-12-31
# 1   None  2019-12-31
# 2   None  2019-12-31
# 3   None  2019-12-31
# 4   None  2019-12-31
# 5   None  2019-12-31
# 6   None  2019-12-31
# 7   None  2019-12-31

# %% [markdown]
# ----------
